# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from pprint import pprint
import json
from datetime import datetime 

# Output unemployment (CSV)
ui_csv = pd.read_csv("Resources/DOL UI 2015 to 2020 6 States.csv")
ui_csv.tail()
# test = ui_csv['Reflecting Week Ended'].dt.isocalendar().week
# test.head
# Out:
#       State Filed week ended Initial Claims Reflecting Week Ended  \
# 1753  Texas        7/11/2020        105,516              7/4/2020
# 1754  Texas        7/18/2020         87,908             7/11/2020
# 1755  Texas        7/25/2020         76,804             7/18/2020
# 1756  Texas         8/1/2020         62,709             7/25/2020
# 1757  Texas         8/8/2020         52,304              8/1/2020
#
#      Continued Claims Covered Employment  Insured Unemployment Rate
# 1753        1,313,086         12,372,188                      10.61
# 1754        1,247,269         12,372,188                      10.08
# 1755        1,338,900         12,372,188                      10.82
# 1756        1,228,250         12,372,188                       9.93
# 1757        1,221,540         12,372,188                       9.87

# %%
# Output state abbreviation conversion file (CSV)
state_abbrevs = pd.read_csv("Resources/state_abbrev.csv")
state_abbrevs.tail()
# Out:
#             State Abbrev Code
# 46       Virginia    Va.   VA
# 47     Washington  Wash.   WA
# 48  West Virginia  W.Va.   WV
# 49      Wisconsin   Wis.   WI
# 50        Wyoming   Wyo.   WY

# %%
# Output unemployment (CSV)
ad_csv = pd.read_csv("Resources/CDC Anxiety Depression Frequency Last_7_Days.csv")
ad_csv["Week Label"] = ad_csv["Week Label"].str.split(" -", n = 1, expand = True)  # Formatting 
ad_csv.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 0  United States     1    Apr 23    23.5    22.7     24.3         22.7 - 24.3
# 1  18 - 29 years     1    Apr 23    32.7    30.2     35.2         30.2 - 35.2
# 2  30 - 39 years     1    Apr 23    25.7    24.1     27.3         24.1 - 27.3
# 3  40 - 49 years     1    Apr 23    24.8    23.3     26.2         23.3 - 26.2
# 4  50 - 59 years     1    Apr 23    23.2    21.5     25.0         21.5 - 25.0
#
#   Quartile range
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
# Output unemployment (CSV)
# ad_csv = pd.read_csv("Resources/CDC Anxiety Depression Frequency Last_7_Days.csv")
# ad_csv["Week Label"] = ad_csv["Week Label"].str.split(" -", n = 1, expand = True)  # Formatting 
string_date_rng_2 = ad_csv['Week Label']
timestamp_date_rng_2 = [datetime.strptime(x,"%b %d") for x in string_date_rng_2]
timestamp_date_rng_2
ad_csv.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-6cf1468f7461> in <module>
#       3 # ad_csv["Week Label"] = ad_csv["Week Label"].str.split(" -", n = 1, expand = True)  # Formatting
#       4 string_date_rng_2 = ad_csv['Week Label']
# ----> 5 timestamp_date_rng_2 = [datetime.strptime(x,"%b %d") for x in string_date_rng_2]
#       6 timestamp_date_rng_2
#       7 ad_csv.head()
#
# <ipython-input-14-6cf1468f7461> in <listcomp>(.0)
#       3 # ad_csv["Week Label"] = ad_csv["Week Label"].str.split(" -", n = 1, expand = True)  # Formatting
#       4 string_date_rng_2 = ad_csv['Week Label']
# ----> 5 timestamp_date_rng_2 = [datetime.strptime(x,"%b %d") for x in string_date_rng_2]
#       6 timestamp_date_rng_2
#       7 ad_csv.head()
#
# ~\anaconda3.1\envs\pythondata\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~\anaconda3.1\envs\pythondata\lib\_strptime.py in _strptime(data_string, format)
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# --> 352         raise ValueError("unconverted data remains: %s" %
#     353                           data_string[found.end():])
#     354
#
# ValueError: unconverted data remains:

# %%
# test = ui_csv['Week Label'].dt.isocalendar().week
# test
