# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from pprint import pprint
import json
from datetime import datetime 

# Pull in UI DF
ui_combo = pd.read_csv("../Resources/ui_combo.csv")
ui_combo
# Out:
#           State  month  Insured Unemployment Rate         Period
# 0    California      1                   2.514545  2015-2019 Avg
# 1    California      2                   2.522500  2015-2019 Avg
# 2    California      3                   2.479545  2015-2019 Avg
# 3    California      4                   2.309091  2015-2019 Avg
# 4    California      5                   2.106667  2015-2019 Avg
# ..          ...    ...                        ...            ...
# 115       Texas      4                   7.395000           2020
# 116       Texas      5                  10.356000           2020
# 117       Texas      6                  10.277500           2020
# 118       Texas      7                  10.360000           2020
# 119       Texas      8                   9.870000           2020
#
# [120 rows x 4 columns]

# %%
ui_base_parse = ui_combo[ui_combo["Period"] != '2020']
ui_base_parse.head()
# Out:
#          State  month  Insured Unemployment Rate         Period
# 0   California      1                   2.514545  2015-2019 Avg
# 1   California      2                   2.522500  2015-2019 Avg
# 2   California      3                   2.479545  2015-2019 Avg
# 3   California      4                   2.309091  2015-2019 Avg
# 4   California      5                   2.106667  2015-2019 Avg
# ..         ...    ...                        ...            ...
# 67       Texas      8                   1.284091  2015-2019 Avg
# 68       Texas      9                   1.215455  2015-2019 Avg
# 69       Texas     10                   1.163636  2015-2019 Avg
# 70       Texas     11                   1.170476  2015-2019 Avg
# 71       Texas     12                   1.227083  2015-2019 Avg
#
# [72 rows x 4 columns]

# %%
ui_2020_parse = ui_combo[ui_combo["Period"] == '2020']
ui_2020_parse.head()
# Out:
#          State  month  Insured Unemployment Rate Period
# 72  California      1                     2.1100   2020
# 73  California      2                     2.1200   2020
# 74  California      3                     3.2600   2020
# 75  California      4                    15.2175   2020
# 76  California      5                    16.3140   2020

# %%
ui_2020_parse.hist(by=ui_combo['State'], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021EEC55AD00>,
# ...
#       dtype=object)

# %%
ui_combo = DataFrame(rand(10, 4), columns=['a', 'b', 'c', 'd'])

df2.plot(kind='bar');
