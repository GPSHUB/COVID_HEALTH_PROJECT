# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from pprint import pprint
import json
from datetime import datetime 

# Output unemployment (CSV)
ui_csv = pd.read_csv("../Resources/ui_clean.csv")
ad_csv = pd.read_csv("../Resources/ad_clean.csv")
ad_csv
# Out:
#                                               Indicator              Group  \
# 0                       Symptoms of Depressive Disorder  National Estimate
# 1                       Symptoms of Depressive Disorder             By Age
# 2                       Symptoms of Depressive Disorder             By Age
# 3                       Symptoms of Depressive Disorder             By Age
# 4                       Symptoms of Depressive Disorder             By Age
# ...                                                 ...                ...
# 2515  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2516  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2517  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2518  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2519  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
#               State       Subgroup  Week  Week Label  Value  Low CI  High CI  \
# 0     United States  United States     1  2020-04-23   23.5    22.7     24.3
# 1     United States  18 - 29 years     1  2020-04-23   32.7    30.2     35.2
# 2     United States  30 - 39 years     1  2020-04-23   25.7    24.1     27.3
# 3     United States  40 - 49 years     1  2020-04-23   24.8    23.3     26.2
# 4     United States  50 - 59 years     1  2020-04-23   23.2    21.5     25.0
# ...             ...            ...   ...         ...    ...     ...      ...
# 2515       Virginia       Virginia    12  2020-07-16   38.3    34.0     42.7
# 2516     Washington     Washington    12  2020-07-16   43.8    39.3     48.5
# 2517  West Virginia  West Virginia    12  2020-07-16   37.0    31.4     42.8
# 2518      Wisconsin      Wisconsin    12  2020-07-16   33.3    28.9     37.9
# 2519        Wyoming        Wyoming    12  2020-07-16   41.3    34.9     47.9
#
#      Confidence Interval Quartile range  Weeknum
# 0            22.7 - 24.3            NaN       17
# 1            30.2 - 35.2            NaN       17
# 2            24.1 - 27.3            NaN       17
# 3            23.3 - 26.2            NaN       17
# 4            21.5 - 25.0            NaN       17
# ...                  ...            ...      ...
# 2515         34.0 - 42.7      37.2-40.5       29
# 2516         39.3 - 48.5      43.6-50.2       29
# 2517         31.4 - 42.8      31.8-37.1       29
# 2518         28.9 - 37.9      31.8-37.1       29
# 2519         34.9 - 47.9      40.6-43.5       29
#
# [2520 rows x 12 columns]
