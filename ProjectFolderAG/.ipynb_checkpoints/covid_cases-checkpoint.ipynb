# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import gmaps
import os
from scipy.stats import linregress
from citipy import citipy
import json
from pprint import pprint 
from datetime import datetime

output_data = "output_data/clean_covid.csv"

# %%
covid_df = pd.DataFrame(columns = ['Date'])

# %%
states = ["ca", "tx", "sd", "md", "ga", "fl"]

index = 0
 

for state in states:
    
    url = f"https://api.covidtracking.com/v1/states/{state}/daily.json"
    
    response = requests.get(url)
    response_json = response.json()
    
    for row in response_json:
        
        try:
            print(f"Printing data for {state} and index: {index}")

            
            covid_df.loc[index, 'Date'] = row['date']
            covid_df.loc[index, 'State'] = row['state']
            covid_df.loc[index, 'Positive'] = row['positive']
            covid_df.loc[index, 'Positive Increase'] = row['positiveIncrease']
            covid_df.loc[index, 'Death Increase'] = row['deathIncrease']
            covid_df.loc[index, 'Death Confirmed'] = row['death']
            covid_df.loc[index, 'Death Probable'] = row['deathProbable']
            covid_df.loc[index, 'Hospitalized'] = row['hospitalized']
            covid_df.loc[index, 'Negative'] = row['negative']
            covid_df.loc[index, 'Recovered'] = row['recovered']
            covid_df.loc[index, 'Total'] = row['total']
            covid_df.loc[index, 'Total Test Results'] = row['totalTestResults']
           
            index += 1
           

        except (KeyError, IndexError):
            print("info not found. Skipping....")
# Out:
# Printing data for ca and index: 0
# Printing data for ca and index: 1
# Printing data for ca and index: 2
# Printing data for ca and index: 3
# Printing data for ca and index: 4
# Printing data for ca and index: 5
# Printing data for ca and index: 6
# Printing data for ca and index: 7
# Printing data for ca and index: 8
# Printing data for ca and index: 9
# Printing data for ca and index: 10
# Printing data for ca and index: 11
# Printing data for ca and index: 12
# Printing data for ca and index: 13
# Printing data for ca and index: 14
# Printing data for ca and index: 15
# Printing data for ca and index: 16
# Printing data for ca and index: 17
# Printing data for ca and index: 18
# Printing data for ca and index: 19
# Printing data for ca and index: 20
# Printing data for ca and index: 21
# Printing data for ca and index: 22
# Printing data for ca and index: 23
# Printing data for ca and index: 24
# Printing data for ca and index: 25
# Printing data for ca and index: 26
# ...

# %%
covid_df
# Out:
#           Date State  Positive  Positive Increase  Death Increase  \
# 0     20200824    CA  668615.0             4946.0            18.0
# 1     20200823    CA  663669.0             6777.0           146.0
# 2     20200822    CA  656892.0             6556.0           167.0
# 3     20200821    CA  650336.0             5585.0           135.0
# 4     20200820    CA  644751.0             5920.0           163.0
# ...        ...   ...       ...                ...             ...
# 1035  20200308    FL      17.0                3.0             0.0
# 1036  20200307    FL      14.0                5.0             0.0
# 1037  20200306    FL       9.0                0.0             0.0
# 1038  20200305    FL       9.0                7.0             0.0
# 1039  20200304    FL       2.0                0.0             0.0
#
#       Death Confirmed  Death Probable  Hospitalized   Negative  Recovered  \
# 0             12152.0             NaN           NaN  9983872.0        NaN
# ...

# %%
test = covid_df.copy()

# %%
test["Date Format"] = ""

# %%
test["Date Format"] = pd.to_datetime(test["Date"], format="%Y%m%d")

# %%
test["Weeknum"] = ""

# %%
test["Weeknum"] = test["Date Format"].dt.isocalendar().week

# %%
test.to_csv(output_data, index=False)

# %%
test_group_edit = test.rename(columns = {"State":"Code"})
test_group_edit
# Out:
#           Date Code  Positive  Positive Increase  Death Increase  \
# 0     20200824   CA  668615.0             4946.0            18.0
# 1     20200823   CA  663669.0             6777.0           146.0
# 2     20200822   CA  656892.0             6556.0           167.0
# 3     20200821   CA  650336.0             5585.0           135.0
# 4     20200820   CA  644751.0             5920.0           163.0
# ...        ...  ...       ...                ...             ...
# 1035  20200308   FL      17.0                3.0             0.0
# 1036  20200307   FL      14.0                5.0             0.0
# 1037  20200306   FL       9.0                0.0             0.0
# 1038  20200305   FL       9.0                7.0             0.0
# 1039  20200304   FL       2.0                0.0             0.0
#
#       Death Confirmed  Death Probable  Hospitalized   Negative  Recovered  \
# 0             12152.0             NaN           NaN  9983872.0        NaN
# ...

# %%
state_df = pd.read_csv("Resources/state_abbrev.csv")

# %%
merge_group = pd.merge(test_group_edit, state_df, on = 'Code', how = 'left')
merge_group
# Out:
#           Date Code  Positive  Positive Increase  Death Increase  \
# 0     20200824   CA  668615.0             4946.0            18.0
# 1     20200823   CA  663669.0             6777.0           146.0
# 2     20200822   CA  656892.0             6556.0           167.0
# 3     20200821   CA  650336.0             5585.0           135.0
# 4     20200820   CA  644751.0             5920.0           163.0
# ...        ...  ...       ...                ...             ...
# 1035  20200308   FL      17.0                3.0             0.0
# 1036  20200307   FL      14.0                5.0             0.0
# 1037  20200306   FL       9.0                0.0             0.0
# 1038  20200305   FL       9.0                7.0             0.0
# 1039  20200304   FL       2.0                0.0             0.0
#
#       Death Confirmed  Death Probable  Hospitalized   Negative  Recovered  \
# 0             12152.0             NaN           NaN  9983872.0        NaN
# ...

# %%
merge_group_df = merge_group.groupby(['State','Weeknum'])["Positive Increase"].mean()

# %%
test_group_new = pd.DataFrame(merge_group_df)
test_group_new
# Out:
#                     Positive Increase
# State      Weeknum
# California 10                7.000000
#            11               29.285714
#            12              177.571429
#            13              596.000000
#            14             1104.285714
# ...                               ...
# Texas      31             6975.571429
#            32             7982.428571
#            33             7031.428571
#            34             5993.571429
#            35             2847.000000
#
# [156 rows x 1 columns]

# %%
test_group_new.reset_index(inplace = True)

# %%
covid_ca = test_group_new.loc[test_group_new["State"]  == 'California']
covid_ca.head()
# Out:
#         State  Weeknum  Positive Increase
# 0  California       10           7.000000
# 1  California       11          29.285714
# 2  California       12         177.571429
# 3  California       13         596.000000
# 4  California       14        1104.285714

# %%
covid_ca_wk = covid_ca['Weeknum']
covid_ca_value = covid_ca['Positive Increase']

plt.plot(covid_ca_wk, covid_ca_value, c = "tab:blue")
plt.xlim(17, 29)
plt.ylabel("# of New Covid-19 Cases")
plt.xlabel("Weeknum")
plt.title("California")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/covid_ca.png")

# %%
covid_fl = test_group_new.loc[test_group_new["State"]  == 'Florida']
covid_fl.head()
# Out:
#       State  Weeknum  Positive Increase
# 26  Florida       10           3.000000
# 27  Florida       11          14.142857
# 28  Florida       12         102.000000
# 29  Florida       13         488.000000
# 30  Florida       14        1129.285714

# %%
covid_fl_wk = covid_fl['Weeknum']
covid_fl_value = covid_fl['Positive Increase']

plt.plot(covid_fl_wk, covid_fl_value, c = "tab:blue")
plt.xlim(17, 29)
plt.ylabel("# of New Covid-19 Cases")
plt.xlabel("Weeknum")
plt.title("Florida")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/covid_fl.png")

# %%
covid_ga = test_group_new.loc[test_group_new["State"]  == 'Georgia']
covid_ga.head()
# Out:
#       State  Weeknum  Positive Increase
# 52  Georgia       10           1.000000
# 53  Georgia       11          13.142857
# 54  Georgia       12          71.571429
# 55  Georgia       13         293.000000
# 56  Georgia       14         570.857143

# %%
covid_ga_wk = covid_ga['Weeknum']
covid_ga_value = covid_ga['Positive Increase']

plt.plot(covid_ga_wk, covid_ga_value, c = "tab:blue")
plt.xlim(17, 29)
plt.ylabel("# of New Covid-19 Cases")
plt.xlabel("Weeknum")
plt.title("Georgia")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/covid_ga.png")

# %%
covid_md = test_group_new.loc[test_group_new["State"]  == 'Maryland']
covid_md.head()
# Out:
#        State  Weeknum  Positive Increase
# 78  Maryland       10           0.750000
# 79  Maryland       11           4.000000
# 80  Maryland       12          30.428571
# 81  Maryland       13         142.142857
# 82  Maryland       14         338.571429

# %%
covid_md_wk = covid_md['Weeknum']
covid_md_value = covid_md['Positive Increase']

plt.plot(covid_md_wk, covid_md_value, c = "tab:blue")
plt.xlim(17, 29)
plt.ylabel("# of New Covid-19 Cases")
plt.xlabel("Weeknum")
plt.title("Maryland")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/covid_md.png")

# %%
covid_sd = test_group_new.loc[test_group_new["State"]  == 'South Dakota']
covid_sd.head()
# Out:
#             State  Weeknum  Positive Increase
# 104  South Dakota       10           0.000000
# 105  South Dakota       11           1.285714
# 106  South Dakota       12           1.714286
# 107  South Dakota       13           9.857143
# 108  South Dakota       14          21.428571

# %%
covid_sd_wk = covid_sd['Weeknum']
covid_sd_value = covid_sd['Positive Increase']

plt.plot(covid_sd_wk, covid_sd_value, c = "tab:blue")
plt.xlim(17, 29)
plt.ylabel("# of New Covid-19 Cases")
plt.xlabel("Weeknum")
plt.title("South Dakota")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/covid_sd.png")

# %%
covid_tx = test_group_new.loc[test_group_new["State"]  == 'Texas']
covid_tx.head()
# Out:
#      State  Weeknum  Positive Increase
# 130  Texas       10           1.400000
# 131  Texas       11           6.857143
# 132  Texas       12          39.714286
# 133  Texas       13         316.857143
# 134  Texas       14         608.571429

# %%
covid_tx_wk = covid_tx['Weeknum']
covid_tx_value = covid_tx['Positive Increase']

plt.plot(covid_tx_wk, covid_tx_value, c = "tab:blue")
plt.xlim(17, 29)
plt.ylabel("# of New Covid-19 Cases")
plt.xlabel("Weeknum")
plt.title("Texas")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/covid_tx.png")

# %%
ad_df = pd.read_csv("output_data/anx_dep_by_state.csv")

# %%
ad_df.head()
# Out:
#                                            Indicator     Group       State  \
# 0  Symptoms of Anxiety Disorder or Depressive Dis...  By State     Alabama
# 1  Symptoms of Anxiety Disorder or Depressive Dis...  By State      Alaska
# 2  Symptoms of Anxiety Disorder or Depressive Dis...  By State     Arizona
# 3  Symptoms of Anxiety Disorder or Depressive Dis...  By State    Arkansas
# 4  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
#
#      Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 0     Alabama     1  4/23/2020   30.3    24.8     36.2         24.8 - 36.2
# 1      Alaska     1  4/23/2020   31.5    28.8     34.4         28.8 - 34.4
# 2     Arizona     1  4/23/2020   36.4    32.3     40.7         32.3 - 40.7
# 3    Arkansas     1  4/23/2020   38.0    33.1     43.1         33.1 - 43.1
# 4  California     1  4/23/2020   37.4    34.2     40.6         34.2 - 40.6
#
#   Quartile range  Weeknum
# 0    25.6 - 33.3       17
# ...

# %%
##filter by state:California, Florida, Georgia, Maryland, South Dakota, Texas
ca_ad_df = ad_df.loc[ad_df["State"]  == 'California']
ca_ad_df.head()
# Out:
#                                              Indicator     Group       State  \
# 4    Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 55   Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 106  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 157  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 208  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
#
#        Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 4    California     1  4/23/2020   37.4    34.2     40.6         34.2 - 40.6
# 55   California     2   5/7/2020   34.4    30.4     38.6         30.4 - 38.6
# 106  California     3  5/14/2020   38.8    35.1     42.6         35.1 - 42.6
# 157  California     4  5/21/2020   36.2    32.8     39.7         32.8 - 39.7
# 208  California     5  5/28/2020   38.6    36.3     40.8         36.3 - 40.8
#
#     Quartile range  Weeknum
# ...

# %%
ca_wk_df = ca_ad_df['Weeknum']
ca_value = ca_ad_df['Value']

plt.plot(ca_wk_df, ca_value, c = "dodgerblue")
plt.ylim(25, 50)
plt.ylabel("% of Anxiety or Depressive Disorder")
plt.xlabel("Weeknum")
plt.title("California")
plt.axvline(x = 20, c = "red")
plt.axvline(x = 22, c = "red")
plt.axvline(x = 26, c = "red")
plt.axvline(x = 27, c = "red")
plt.savefig("output_data/anxiety_ca.png")

# %%
fl_ad_df = ad_df.loc[ad_df["State"]  == 'Florida']
fl_ad_df.head()
# Out:
#                                              Indicator     Group    State  \
# 9    Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 60   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 111  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 162  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 213  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
#
#     Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 9    Florida     1  4/23/2020   36.8    33.9     39.8         33.9 - 39.8
# 60   Florida     2   5/7/2020   33.6    28.5     39.1         28.5 - 39.1
# 111  Florida     3  5/14/2020   33.5    30.2     37.0         30.2 - 37.0
# 162  Florida     4  5/21/2020   39.1    36.3     41.9         36.3 - 41.9
# 213  Florida     5  5/28/2020   40.0    36.6     43.4         36.6 - 43.4
#
#     Quartile range  Weeknum
# 9      36.8 - 41.4       17
# ...

# %%
fl_wk_df = fl_ad_df['Weeknum']
fl_value = fl_ad_df['Value']

plt.plot(fl_wk_df, fl_value, c = "dodgerblue")
plt.ylim(25, 50)
plt.ylabel("% of Anxiety or Depressive Disorder")
plt.xlabel("Weeknum")
plt.title("Florida")
plt.axvline(x = 20, c = "red")
plt.axvline(x = 22, c = "red")
plt.axvline(x = 26, c = "red")
plt.axvline(x = 27, c = "red")
plt.savefig("output_data/anxiety_fl.png")

# %%
ga_ad_df = ad_df.loc[ad_df["State"]  == 'Georgia']
ga_ad_df.head()
# Out:
#                                              Indicator     Group    State  \
# 10   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 61   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 112  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 163  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 214  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
#
#     Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 10   Georgia     1  4/23/2020   36.2    31.8     40.7         31.8 - 40.7
# 61   Georgia     2   5/7/2020   34.3    28.2     40.8         28.2 - 40.8
# 112  Georgia     3  5/14/2020   33.6    29.1     38.3         29.1 - 38.3
# 163  Georgia     4  5/21/2020   37.5    33.3     41.8         33.3 - 41.8
# 214  Georgia     5  5/28/2020   34.9    31.0     39.0         31.0 - 39.0
#
#     Quartile range  Weeknum
# 10     34.8 - 36.7       17
# ...

# %%
ga_wk_df = ga_ad_df['Weeknum']
ga_value = ga_ad_df['Value']

plt.plot(ga_wk_df, ga_value, c = "dodgerblue")
plt.ylim(25, 50)
plt.ylabel("% of Anxiety or Depressive Disorder")
plt.xlabel("Weeknum")
plt.title("Georgia")
plt.axvline(x = 20, c = "red")
plt.axvline(x = 22, c = "red")
plt.axvline(x = 26, c = "red")
plt.axvline(x = 27, c = "red")
plt.savefig("output_data/anxiety_ga.png")

# %%
md_ad_df = ad_df.loc[ad_df["State"]  == 'Maryland']
md_ad_df.head()
# Out:
#                                              Indicator     Group     State  \
# 20   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 71   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 122  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 173  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 224  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
#
#      Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 20   Maryland     1  4/23/2020   32.9    29.3     36.6         29.3 - 36.6
# 71   Maryland     2   5/7/2020   34.6    28.4     41.3         28.4 - 41.3
# 122  Maryland     3  5/14/2020   32.7    28.8     36.8         28.8 - 36.8
# 173  Maryland     4  5/21/2020   31.6    27.6     35.9         27.6 - 35.9
# 224  Maryland     5  5/28/2020   30.8    27.5     34.2         27.5 - 34.2
#
#     Quartile range  Weeknum
# 20     25.6 - 33.3       17
# ...

# %%
md_wk_df = md_ad_df['Weeknum']
md_value = md_ad_df['Value']

plt.plot(md_wk_df, md_value, c = "dodgerblue")
plt.ylim(25, 50)
plt.ylabel("% of Anxiety or Depressive Disorder")
plt.xlabel("Weeknum")
plt.title("Maryland")
plt.axvline(x = 20, c = "red")
plt.axvline(x = 22, c = "red")
plt.axvline(x = 26, c = "red")
plt.axvline(x = 27, c = "red")
plt.savefig("output_data/anxiety_md.png")

# %%
sd_ad_df = ad_df.loc[ad_df["State"]  == 'South Dakota']
sd_ad_df.head()
# Out:
#                                              Indicator     Group  \
# 41   Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 92   Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 143  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 194  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 245  Symptoms of Anxiety Disorder or Depressive Dis...  By State
#
#             State      Subgroup  Week Week Label  Value  Low CI  High CI  \
# 41   South Dakota  South Dakota     1  4/23/2020   25.6    20.5     31.1
# 92   South Dakota  South Dakota     2   5/7/2020   29.8    21.5     39.2
# 143  South Dakota  South Dakota     3  5/14/2020   27.8    21.1     35.2
# 194  South Dakota  South Dakota     4  5/21/2020   36.3    30.7     42.2
# 245  South Dakota  South Dakota     5  5/28/2020   29.7    25.3     34.4
#
#     Confidence Interval Quartile range  Weeknum
# 41          20.5 - 31.1    25.6 - 33.3       17
# ...

# %%
sd_wk_df = sd_ad_df['Weeknum']
sd_value = sd_ad_df['Value']

plt.plot(sd_wk_df, sd_value, c = "dodgerblue")
plt.ylim(25, 50)
plt.ylabel("% of Anxiety or Depressive Disorder")
plt.xlabel("Weeknum")
plt.title("South Dakota")
plt.axvline(x = 20, c = "red")
plt.axvline(x = 22, c = "red")
plt.axvline(x = 26, c = "red")
plt.axvline(x = 27, c = "red")
plt.savefig("output_data/anxiety_sd.png")

# %%
tx_ad_df = ad_df.loc[ad_df["State"]  == 'Texas']
tx_ad_df.head()
# Out:
#                                              Indicator     Group  State  \
# 43   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Texas
# 94   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Texas
# 145  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Texas
# 196  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Texas
# 247  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Texas
#
#     Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 43     Texas     1  4/23/2020   34.9    30.8     39.2         30.8 - 39.2
# 94     Texas     2   5/7/2020   35.9    31.4     40.6         31.4 - 40.6
# 145    Texas     3  5/14/2020   34.8    31.8     37.9         31.8 - 37.9
# 196    Texas     4  5/21/2020   37.7    33.8     41.7         33.8 - 41.7
# 247    Texas     5  5/28/2020   36.9    33.7     40.2         33.7 - 40.2
#
#     Quartile range  Weeknum
# 43     34.8 - 36.7       17
# 94     33.5 - 36.0       19
# ...

# %%
tx_wk_df = tx_ad_df['Weeknum']
tx_value = tx_ad_df['Value']

plt.plot(tx_wk_df, tx_value, c = "dodgerblue")
plt.ylim(25, 50)
plt.ylabel("% of Anxiety or Depressive Disorder")
plt.xlabel("Weeknum")
plt.title("Texas")
plt.axvline(x = 20, c = "red")
plt.axvline(x = 22, c = "red")
plt.axvline(x = 26, c = "red")
plt.axvline(x = 27, c = "red")
plt.savefig("output_data/anxiety_tx.png")

# %%
combo_d1 = covid_ca['Weeknum']
combo_d2 = ca_ad_df['Weeknum']
data1 = covid_ca_value
data2 = ca_value

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Weeknum')
plt.xlim(17, 29)
ax1.set_ylabel('# of New Covid-19 Cases', color=color)
ax1.plot(combo_d1, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('% of Anxiety or Depressive Disorder', color="tab:blue")  
plt.ylim(26, 46)
ax2.plot(combo_d2, data2, color="tab:blue")
ax2.tick_params(axis='y', labelcolor="tab:blue")

fig.tight_layout()  
plt.title("California")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/combo_ca.png")
plt.show()

# %%
ca_all = pd.merge(covid_ca, ca_ad_df, on = "Weeknum", how = "left")
ca_all.head()
# Out:
#       State_x  Weeknum  Positive Increase Indicator Group State_y Subgroup  \
# 0  California       10           7.000000       NaN   NaN     NaN      NaN
# 1  California       11          29.285714       NaN   NaN     NaN      NaN
# 2  California       12         177.571429       NaN   NaN     NaN      NaN
# 3  California       13         596.000000       NaN   NaN     NaN      NaN
# 4  California       14        1104.285714       NaN   NaN     NaN      NaN
#
#    Week Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 0   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 1   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 2   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 3   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 4   NaN        NaN    NaN     NaN      NaN                 NaN            NaN

# %%
new_ca = ca_all.dropna(how="any")
new_ca.head()
# Out:
#        State_x  Weeknum  Positive Increase  \
# 7   California       17        1690.142857
# 9   California       19        1866.285714
# 10  California       20        1737.000000
# 11  California       21        1981.571429
# 12  California       22        2553.285714
#
#                                             Indicator     Group     State_y  \
# 7   Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 9   Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 10  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 11  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
# 12  Symptoms of Anxiety Disorder or Depressive Dis...  By State  California
#
#       Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 7   California   1.0  4/23/2020   37.4    34.2     40.6         34.2 - 40.6
# 9   California   2.0   5/7/2020   34.4    30.4     38.6         30.4 - 38.6
# ...

# %%
x_value = new_ca["Positive Increase"]
y_value = new_ca["Value"]

plt.scatter(x_value, y_value, c = "tab:blue", edgecolors= "dimgray")
plt.title('California Covid-19 Cases vs Anixety or Depressive Disorder %')
plt.xlabel('# of New Covid-19 Cases')
plt.ylabel('% of Anxiety or Depressive Disorder')
#Regeression Analysis
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (5000,37.5), fontsize = 15, color="red")
plt.plot(x_value, regress_values, "r-")
plt.savefig('output_data/scatter_combo_ca.png')
plt.show()
print(f'rsquared = {rvalue**2}')
# Out:
# rsquared = 0.62153124596546

# %%
combo_d1 = covid_fl['weeknum']
combo_d2 = fl_ad_df['Weeknum']
data1 = covid_fl_value
data2 = fl_value

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Weeknum')
plt.xlim(17, 29)
ax1.set_ylabel('# of New Covid-19 Cases', color=color)
ax1.plot(combo_d1, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('% of Anxiety or Depressive Disorder', color="tab:blue")  
plt.ylim(26, 46)
ax2.plot(combo_d2, data2, color="tab:blue")
ax2.tick_params(axis='y', labelcolor="tab:blue")

fig.tight_layout()  
plt.title("Florida")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/combo_fl.png")
plt.show()

# %%
fl_all = pd.merge(covid_fl, fl_ad_df, on = "Weeknum", how = "left")
fl_all.head()
# Out:
#    State_x  Weeknum  Positive Increase Indicator Group State_y Subgroup  Week  \
# 0  Florida       10           3.000000       NaN   NaN     NaN      NaN   NaN
# 1  Florida       11          14.142857       NaN   NaN     NaN      NaN   NaN
# 2  Florida       12         102.000000       NaN   NaN     NaN      NaN   NaN
# 3  Florida       13         488.000000       NaN   NaN     NaN      NaN   NaN
# 4  Florida       14        1129.285714       NaN   NaN     NaN      NaN   NaN
#
#   Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 0        NaN    NaN     NaN      NaN                 NaN            NaN
# 1        NaN    NaN     NaN      NaN                 NaN            NaN
# 2        NaN    NaN     NaN      NaN                 NaN            NaN
# 3        NaN    NaN     NaN      NaN                 NaN            NaN
# 4        NaN    NaN     NaN      NaN                 NaN            NaN

# %%
new_fl = fl_all.dropna(how="any")
new_fl.head()
# Out:
#     State_x  Weeknum  Positive Increase  \
# 7   Florida       17         790.285714
# 9   Florida       19         645.428571
# 10  Florida       20         713.142857
# 11  Florida       21         754.142857
# 12  Florida       22         756.571429
#
#                                             Indicator     Group  State_y  \
# 7   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 9   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 10  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 11  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
# 12  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Florida
#
#    Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 7   Florida   1.0  4/23/2020   36.8    33.9     39.8         33.9 - 39.8
# 9   Florida   2.0   5/7/2020   33.6    28.5     39.1         28.5 - 39.1
# ...

# %%
x_value = new_fl["Positive Increase"]
y_value = new_fl["Value"]

plt.scatter(x_value, y_value, c = "tab:blue", edgecolors= "dimgray")
plt.title('Florida Covid-19 Cases vs Anixety or Depressive Disorder %')
plt.xlabel('# of New Covid-19 Cases')
plt.ylabel('% of Anxiety or Depressive Disorder')
#Regeression Analysis
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (5000,37.5), fontsize = 15, color="red")
plt.plot(x_value, regress_values, "r-")
plt.savefig('output_data/scatter_combo_fl.png')
plt.show()
print(f'rsquared = {rvalue**2}')
# Out:
# rsquared = 0.35889718799857806

# %%
combo_d1 = covid_ga['Weeknum']
combo_d2 = ga_ad_df['Weeknum']
data1 = covid_ga_value
data2 = ga_value

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Weeknum')
plt.xlim(17, 29)
ax1.set_ylabel('# of New Covid-19 Cases', color=color)
ax1.plot(combo_d1, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('% of Anxiety or Depressive Disorder', color="tab:blue")  
plt.ylim(26, 46)
ax2.plot(combo_d2, data2, color="tab:blue")
ax2.tick_params(axis='y', labelcolor="tab:blue")

fig.tight_layout()  
plt.title("Georgia")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/combo_ga.png")
plt.show()

# %%
ga_all = pd.merge(covid_ga, ga_ad_df, on = "Weeknum", how = "left")
ga_all.head()
# Out:
#    State_x  Weeknum  Positive Increase Indicator Group State_y Subgroup  Week  \
# 0  Georgia       10           1.000000       NaN   NaN     NaN      NaN   NaN
# 1  Georgia       11          13.142857       NaN   NaN     NaN      NaN   NaN
# 2  Georgia       12          71.571429       NaN   NaN     NaN      NaN   NaN
# 3  Georgia       13         293.000000       NaN   NaN     NaN      NaN   NaN
# 4  Georgia       14         570.857143       NaN   NaN     NaN      NaN   NaN
#
#   Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 0        NaN    NaN     NaN      NaN                 NaN            NaN
# 1        NaN    NaN     NaN      NaN                 NaN            NaN
# 2        NaN    NaN     NaN      NaN                 NaN            NaN
# 3        NaN    NaN     NaN      NaN                 NaN            NaN
# 4        NaN    NaN     NaN      NaN                 NaN            NaN

# %%
new_ga = ga_all.dropna(how="any")
new_ga.head()
# Out:
#     State_x  Weeknum  Positive Increase  \
# 7   Georgia       17         728.571429
# 9   Georgia       19         691.285714
# 10  Georgia       20         608.571429
# 11  Georgia       21         733.857143
# 12  Georgia       22         592.571429
#
#                                             Indicator     Group  State_y  \
# 7   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 9   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 10  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 11  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
# 12  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Georgia
#
#    Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 7   Georgia   1.0  4/23/2020   36.2    31.8     40.7         31.8 - 40.7
# 9   Georgia   2.0   5/7/2020   34.3    28.2     40.8         28.2 - 40.8
# ...

# %%
x_value = new_ga["Positive Increase"]
y_value = new_ga["Value"]

plt.scatter(x_value, y_value, c = "tab:blue", edgecolors= "dimgray")
plt.title('Georgia Covid-19 Cases vs Anixety or Depressive Disorder %')
plt.xlabel('# of New Covid-19 Cases')
plt.ylabel('% of Anxiety or Depressive Disorder')
#Regeression Analysis
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (2500,37.5), fontsize = 15, color="red")
plt.plot(x_value, regress_values, "r-")
plt.savefig('output_data/scatter_combo_ga.png')
plt.show()
print(f'rsquared = {rvalue**2}')
# Out:
# rsquared = 0.6297168300735655

# %%
combo_d1 = covid_md['Weeknum']
combo_d2 = md_ad_df['Weeknum']
data1 = covid_md_value
data2 = md_value

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Weeknum')
plt.xlim(17, 29)
ax1.set_ylabel('# of New Covid-19 Cases', color=color)
ax1.plot(combo_d1, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('% of Anxiety or Depressive Disorder', color="tab:blue")  
plt.ylim(26, 46)
ax2.plot(combo_d2, data2, color="tab:blue")
ax2.tick_params(axis='y', labelcolor="tab:blue")

fig.tight_layout()  
plt.title("Maryland")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/combo_md.png")
plt.show()

# %%
md_all = pd.merge(covid_md, md_ad_df, on = "Weeknum", how = "left")
md_all.head()
# Out:
#     State_x  Weeknum  Positive Increase Indicator Group State_y Subgroup  \
# 0  Maryland       10           0.750000       NaN   NaN     NaN      NaN
# 1  Maryland       11           4.000000       NaN   NaN     NaN      NaN
# 2  Maryland       12          30.428571       NaN   NaN     NaN      NaN
# 3  Maryland       13         142.142857       NaN   NaN     NaN      NaN
# 4  Maryland       14         338.571429       NaN   NaN     NaN      NaN
#
#    Week Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 0   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 1   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 2   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 3   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 4   NaN        NaN    NaN     NaN      NaN                 NaN            NaN

# %%
new_md = md_all.dropna(how="any")
new_md.head()
# Out:
#      State_x  Weeknum  Positive Increase  \
# 7   Maryland       17         821.571429
# 9   Maryland       19        1017.857143
# 10  Maryland       20         888.142857
# 11  Maryland       21        1072.714286
# 12  Maryland       22         923.571429
#
#                                             Indicator     Group   State_y  \
# 7   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 9   Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 10  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 11  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
# 12  Symptoms of Anxiety Disorder or Depressive Dis...  By State  Maryland
#
#     Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 7   Maryland   1.0  4/23/2020   32.9    29.3     36.6         29.3 - 36.6
# 9   Maryland   2.0   5/7/2020   34.6    28.4     41.3         28.4 - 41.3
# ...

# %%
x_value = new_md["Positive Increase"]
y_value = new_md["Value"]

plt.scatter(x_value, y_value, c = "tab:blue", edgecolors= "dimgray")
plt.title('Maryland Covid-19 Cases vs Anixety or Depressive Disorder %')
plt.xlabel('# of New Covid-19 Cases')
plt.ylabel('% of Anxiety or Depressive Disorder')
#Regeression Analysis
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (500,28), fontsize = 15, color="red")
plt.plot(x_value, regress_values, "r-")
plt.savefig('output_data/scatter_combo_md.png')
plt.show()
print(f'rsquared = {rvalue**2}')
# Out:
# rsquared = 0.09729637551421175

# %%
combo_d1 = covid_sd['Weeknum']
combo_d2 = sd_ad_df['Weeknum']
data1 = covid_sd_value
data2 = sd_value

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Weeknum')
plt.xlim(17, 29)
ax1.set_ylabel('# of New Covid-19 Cases', color=color)
ax1.plot(combo_d1, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('% of Anxiety or Depressive Disorder', color="tab:blue")  
plt.ylim(26, 46)
ax2.plot(combo_d2, data2, color="tab:blue")
ax2.tick_params(axis='y', labelcolor="tab:blue")

fig.tight_layout()  
plt.title("South Dakota")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/combo_sd.png")
plt.show()

# %%
sd_all = pd.merge(covid_sd, sd_ad_df, on = "Weeknum", how = "left")
sd_all.head()
# Out:
#         State_x  Weeknum  Positive Increase Indicator Group State_y Subgroup  \
# 0  South Dakota       10           0.000000       NaN   NaN     NaN      NaN
# 1  South Dakota       11           1.285714       NaN   NaN     NaN      NaN
# 2  South Dakota       12           1.714286       NaN   NaN     NaN      NaN
# 3  South Dakota       13           9.857143       NaN   NaN     NaN      NaN
# 4  South Dakota       14          21.428571       NaN   NaN     NaN      NaN
#
#    Week Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 0   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 1   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 2   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 3   NaN        NaN    NaN     NaN      NaN                 NaN            NaN
# 4   NaN        NaN    NaN     NaN      NaN                 NaN            NaN

# %%
new_sd = sd_all.dropna(how="any")
new_sd.head()
# Out:
#          State_x  Weeknum  Positive Increase  \
# 7   South Dakota       17          82.428571
# 9   South Dakota       19         126.571429
# 10  South Dakota       20          67.142857
# 11  South Dakota       21          82.285714
# 12  South Dakota       22          61.428571
#
#                                             Indicator     Group       State_y  \
# 7   Symptoms of Anxiety Disorder or Depressive Dis...  By State  South Dakota
# 9   Symptoms of Anxiety Disorder or Depressive Dis...  By State  South Dakota
# 10  Symptoms of Anxiety Disorder or Depressive Dis...  By State  South Dakota
# 11  Symptoms of Anxiety Disorder or Depressive Dis...  By State  South Dakota
# 12  Symptoms of Anxiety Disorder or Depressive Dis...  By State  South Dakota
#
#         Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 7   South Dakota   1.0  4/23/2020   25.6    20.5     31.1         20.5 - 31.1
# ...

# %%
x_value = new_sd["Positive Increase"]
y_value = new_sd["Value"]

plt.scatter(x_value, y_value, c = "tab:blue", edgecolors= "dimgray")
plt.title('South Dakota Covid-19 Cases vs Anixety or Depressive Disorder %')
plt.xlabel('# of New Covid-19 Cases')
plt.ylabel('% of Anxiety or Depressive Disorder')
#Regeression Analysis
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (80,28), fontsize = 15, color="red")
plt.plot(x_value, regress_values, "r-")
plt.savefig('output_data/scatter_combo_sd.png')
plt.show()
print(f'rsquared = {rvalue**2}')
# Out:
# rsquared = 0.08386506900730338

# %%
combo_d1 = covid_tx['Weeknum']
combo_d2 = tx_ad_df['Weeknum']
data1 = covid_tx_value
data2 = tx_value

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Weeknum')
plt.xlim(17, 29)
ax1.set_ylabel('# of New Covid-19 Cases', color=color)
ax1.plot(combo_d1, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('% of Anxiety or Depressive Disorder', color="tab:blue")  
plt.ylim(26, 46)
ax2.plot(combo_d2, data2, color="tab:blue")
ax2.tick_params(axis='y', labelcolor="tab:blue")

fig.tight_layout()  
plt.title("Texas")
plt.axvline(x = 20, c = "dimgray")
plt.axvline(x = 22, c = "dimgray")
plt.axvline(x = 26, c = "dimgray")
plt.axvline(x = 27, c = "dimgray")
plt.savefig("output_data/combo_tx.png")
plt.show()

# %%
tx_all = pd.merge(covid_tx, tx_ad_df, on = "Weeknum", how = "left")
tx_all.head()
# Out:
#   State_x  Weeknum  Positive Increase Indicator Group State_y Subgroup  Week  \
# 0   Texas       10           1.400000       NaN   NaN     NaN      NaN   NaN
# 1   Texas       11           6.857143       NaN   NaN     NaN      NaN   NaN
# 2   Texas       12          39.714286       NaN   NaN     NaN      NaN   NaN
# 3   Texas       13         316.857143       NaN   NaN     NaN      NaN   NaN
# 4   Texas       14         608.571429       NaN   NaN     NaN      NaN   NaN
#
#   Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 0        NaN    NaN     NaN      NaN                 NaN            NaN
# 1        NaN    NaN     NaN      NaN                 NaN            NaN
# 2        NaN    NaN     NaN      NaN                 NaN            NaN
# 3        NaN    NaN     NaN      NaN                 NaN            NaN
# 4        NaN    NaN     NaN      NaN                 NaN            NaN

# %%
new_tx = tx_all.dropna(how="any")
new_tx.head()
# Out:
#    State_x  Weeknum  Positive Increase  \
# 7    Texas       17         815.428571
# 9    Texas       19        1045.857143
# 10   Texas       20        1273.571429
# 11   Texas       21        1080.571429
# 12   Texas       22        1277.000000
#
#                                             Indicator     Group State_y  \
# 7   Symptoms of Anxiety Disorder or Depressive Dis...  By State   Texas
# 9   Symptoms of Anxiety Disorder or Depressive Dis...  By State   Texas
# 10  Symptoms of Anxiety Disorder or Depressive Dis...  By State   Texas
# 11  Symptoms of Anxiety Disorder or Depressive Dis...  By State   Texas
# 12  Symptoms of Anxiety Disorder or Depressive Dis...  By State   Texas
#
#    Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 7     Texas   1.0  4/23/2020   34.9    30.8     39.2         30.8 - 39.2
# 9     Texas   2.0   5/7/2020   35.9    31.4     40.6         31.4 - 40.6
# ...

# %%
x_value = new_tx["Positive Increase"]
y_value = new_tx["Value"]

plt.scatter(x_value, y_value, c = "tab:blue", edgecolors= "dimgray")
plt.title('Texas Covid-19 Cases vs Anixety or Depressive Disorder %')
plt.xlabel('# of New Covid-19 Cases')
plt.ylabel('% of Anxiety or Depressive Disorder')
#Regeression Analysis
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept, 2))
plt.annotate(line_eq, (5000,37.5), fontsize = 15, color="red")
plt.plot(x_value, regress_values, "r-")
plt.savefig('output_data/scatter_combo_tx.png')
plt.show()
print(f'rsquared = {rvalue**2}')
# Out:
# rsquared = 0.8010421583702989
