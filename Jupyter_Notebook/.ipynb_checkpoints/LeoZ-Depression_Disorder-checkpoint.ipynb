# %%
## LeoZ_Notebook
# Dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
## import plotly.graph_objects as go
from scipy.stats import linregress

# %%
# Import csv files
ax_csv = pd.read_csv("../Resources/ad_clean.csv")
ax_csv.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 0  United States     1  4/23/2020   23.5    22.7     24.3         22.7 - 24.3
# 1  18 - 29 years     1  4/23/2020   32.7    30.2     35.2         30.2 - 35.2
# 2  30 - 39 years     1  4/23/2020   25.7    24.1     27.3         24.1 - 27.3
# 3  40 - 49 years     1  4/23/2020   24.8    23.3     26.2         23.3 - 26.2
# 4  50 - 59 years     1  4/23/2020   23.2    21.5     25.0         21.5 - 25.0
#
#   Quartile range  Weeknum
# 0            NaN       17
# 1            NaN       17
# 2            NaN       17
# 3            NaN       17
# 4            NaN       17

# %%
ax_csv.dtypes
# Out:
# Indicator               object
# Group                   object
# State                   object
# Subgroup                object
# Week                     int64
# Week Label              object
# Value                  float64
# Low CI                 float64
# High CI                float64
# Confidence Interval     object
# Quartile range          object
# Weeknum                  int64
# dtype: object

# %%
cal = ax_csv.loc[(ax_csv["State"]=="California")&(ax_csv["Subgroup"]=="California")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
cal.head()
# Out:
#                            Indicator     Group       State    Subgroup  Week  \
# 23   Symptoms of Depressive Disorder  By State  California  California     1
# 233  Symptoms of Depressive Disorder  By State  California  California     2
# 443  Symptoms of Depressive Disorder  By State  California  California     3
# 653  Symptoms of Depressive Disorder  By State  California  California     4
# 863  Symptoms of Depressive Disorder  By State  California  California     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 23   4/23/2020   25.4    22.5     28.6         22.5 - 28.6    24.1 - 28.7
# 233   5/7/2020   22.8    19.2     26.8         19.2 - 26.8    20.7 - 23.0
# 443  5/14/2020   28.7    25.3     32.4         25.3 - 32.4      25.7-36.4
# 653  5/21/2020   26.9    23.5     30.5         23.5 - 30.5      25.9-31.1
# 863  5/28/2020   26.9    24.6     29.4         24.6 - 29.4      26.9-31.8
#
#      Weeknum
# 23        17
# 233       19
# 443       20
# 653       21
# 863       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = cal["Value"]
month = cal["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="blue", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="red", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("California")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

# plt.show()

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = cal['Weeknum']
y_values = cal['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.5149155711871584

# %%
tx = ax_csv.loc[(ax_csv["State"]=="Texas")&(ax_csv["Subgroup"]=="Texas")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
tx.head()
# Out:
#                            Indicator     Group  State Subgroup  Week  \
# 62   Symptoms of Depressive Disorder  By State  Texas    Texas     1
# 272  Symptoms of Depressive Disorder  By State  Texas    Texas     2
# 482  Symptoms of Depressive Disorder  By State  Texas    Texas     3
# 692  Symptoms of Depressive Disorder  By State  Texas    Texas     4
# 902  Symptoms of Depressive Disorder  By State  Texas    Texas     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 62   4/23/2020   24.4    21.1     27.9         21.1 - 27.9    24.1 - 28.7
# 272   5/7/2020   25.7    21.8     30.0         21.8 - 30.0    25.7 - 35.5
# 482  5/14/2020   24.9    21.8     28.1         21.8 - 28.1      23.3-25.6
# 692  5/21/2020   28.8    25.1     32.8         25.1 - 32.8      25.9-31.1
# 902  5/28/2020   26.2    23.5     29.0         23.5 - 29.0      24.4-26.8
#
#      Weeknum
# 62        17
# 272       19
# 482       20
# 692       21
# 902       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = tx["Value"]
month = tx["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="blue", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="blue", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Texas")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = tx['Weeknum']
y_values = tx['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.6445337673560257

# %%
ga = ax_csv.loc[(ax_csv["State"]=="Georgia")&(ax_csv["Subgroup"]=="Georgia")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
ga.head()
# Out:
#                            Indicator     Group    State Subgroup  Week  \
# 29   Symptoms of Depressive Disorder  By State  Georgia  Georgia     1
# 239  Symptoms of Depressive Disorder  By State  Georgia  Georgia     2
# 449  Symptoms of Depressive Disorder  By State  Georgia  Georgia     3
# 659  Symptoms of Depressive Disorder  By State  Georgia  Georgia     4
# 869  Symptoms of Depressive Disorder  By State  Georgia  Georgia     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 29   4/23/2020   25.6    21.4     30.2         21.4 - 30.2    24.1 - 28.7
# 239   5/7/2020   25.6    20.7     30.9         20.7 - 30.9    23.1 - 25.6
# 449  5/14/2020   24.8    20.7     29.2         20.7 - 29.2      23.3-25.6
# 659  5/21/2020   27.7    24.2     31.4         24.2 - 31.4      25.9-31.1
# 869  5/28/2020   24.5    21.3     28.1         21.3 - 28.1      24.4-26.8
#
#      Weeknum
# 29        17
# 239       19
# 449       20
# 659       21
# 869       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = ga["Value"]
month = ga["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="blue", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="orange", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Georgia")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = ga['Weeknum']
y_values = ga['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.48653165375837837

# %%
fla = ax_csv.loc[(ax_csv["State"]=="Florida")&(ax_csv["Subgroup"]=="Florida")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
fla.head()
# Out:
#                            Indicator     Group    State Subgroup  Week  \
# 28   Symptoms of Depressive Disorder  By State  Florida  Florida     1
# 238  Symptoms of Depressive Disorder  By State  Florida  Florida     2
# 448  Symptoms of Depressive Disorder  By State  Florida  Florida     3
# 658  Symptoms of Depressive Disorder  By State  Florida  Florida     4
# 868  Symptoms of Depressive Disorder  By State  Florida  Florida     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 28   4/23/2020   22.5    19.7     25.4         19.7 - 25.4    22.2 - 24.0
# 238   5/7/2020   24.8    20.0     30.0         20.0 - 30.0    23.1 - 25.6
# 448  5/14/2020   24.3    21.1     27.7         21.1 - 27.7      23.3-25.6
# 658  5/21/2020   28.6    25.8     31.6         25.8 - 31.6      25.9-31.1
# 868  5/28/2020   29.6    26.9     32.3         26.9 - 32.3      26.9-31.8
#
#      Weeknum
# 28        17
# 238       19
# 448       20
# 658       21
# 868       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = fla["Value"]
month = fla["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="green", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="green", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Florida")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = fla['Weeknum']
y_values = fla['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.6669475829466656

# %%
sd = ax_csv.loc[(ax_csv["State"]=="South Dakota")&(ax_csv["Subgroup"]=="South Dakota")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
sd.head()
# Out:
#                            Indicator     Group         State      Subgroup  \
# 60   Symptoms of Depressive Disorder  By State  South Dakota  South Dakota
# 270  Symptoms of Depressive Disorder  By State  South Dakota  South Dakota
# 480  Symptoms of Depressive Disorder  By State  South Dakota  South Dakota
# 690  Symptoms of Depressive Disorder  By State  South Dakota  South Dakota
# 900  Symptoms of Depressive Disorder  By State  South Dakota  South Dakota
#
#      Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 60      1  4/23/2020   17.5    13.0     22.7         13.0 - 22.7
# 270     2   5/7/2020   20.5    13.5     29.2         13.5 - 29.2
# 480     3  5/14/2020   22.7    16.7     29.7         16.7 - 29.7
# 690     4  5/21/2020   25.8    21.0     31.1         21.0 - 31.1
# 900     5  5/28/2020   20.0    16.0     24.4         16.0 - 24.4
#
#     Quartile range  Weeknum
# 60     16.5 - 20.7       17
# 270    16.7 - 20.6       19
# 480      20.8-23.2       20
# 690      23.0-25.8       21
# 900      17.0-21.4       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = sd["Value"]
month = sd["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="yellow", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="yellow", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("South Dakota")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = sd['Weeknum']
y_values = sd['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.47438188162897255

# %%
md = ax_csv.loc[(ax_csv["State"]=="Maryland")&(ax_csv["Subgroup"]=="Maryland")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
md.head()
# Out:
#                            Indicator     Group     State  Subgroup  Week  \
# 39   Symptoms of Depressive Disorder  By State  Maryland  Maryland     1
# 249  Symptoms of Depressive Disorder  By State  Maryland  Maryland     2
# 459  Symptoms of Depressive Disorder  By State  Maryland  Maryland     3
# 669  Symptoms of Depressive Disorder  By State  Maryland  Maryland     4
# 879  Symptoms of Depressive Disorder  By State  Maryland  Maryland     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 39   4/23/2020   20.9    17.9     24.1         17.9 - 24.1    20.8 - 22.1
# 249   5/7/2020   24.6    18.3     31.8         18.3 - 31.8    23.1 - 25.6
# 459  5/14/2020   20.8    17.9     24.0         17.9 - 24.0      20.8-23.2
# 669  5/21/2020   22.9    19.7     26.5         19.7 - 26.5      21.0-22.9
# 879  5/28/2020   21.9    18.9     25.0         18.9 - 25.0      21.5-24.3
#
#      Weeknum
# 39        17
# 249       19
# 459       20
# 669       21
# 879       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = md["Value"]
month = md["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="purple", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="purple", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Maryland")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = md['Weeknum']
y_values = md['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.14075987796251588

# %%
us = ax_csv.loc[(ax_csv["State"]=="United States")&(ax_csv["Subgroup"]=="United States")&(ax_csv["Indicator"]=="Symptoms of Depressive Disorder")]
us.head()
# Out:
#                            Indicator              Group          State  \
# 0    Symptoms of Depressive Disorder  National Estimate  United States
# 210  Symptoms of Depressive Disorder  National Estimate  United States
# 420  Symptoms of Depressive Disorder  National Estimate  United States
# 630  Symptoms of Depressive Disorder  National Estimate  United States
# 840  Symptoms of Depressive Disorder  National Estimate  United States
#
#           Subgroup  Week Week Label  Value  Low CI  High CI  \
# 0    United States     1  4/23/2020   23.5    22.7     24.3
# 210  United States     2   5/7/2020   24.1    23.0     25.2
# 420  United States     3  5/14/2020   24.4    23.7     25.2
# 630  United States     4  5/21/2020   24.9    24.1     25.7
# 840  United States     5  5/28/2020   25.3    24.7     25.8
#
#     Confidence Interval Quartile range  Weeknum
# 0           22.7 - 24.3            NaN       17
# 210         23.0 - 25.2            NaN       19
# 420         23.7 - 25.2            NaN       20
# 630         24.1 - 25.7            NaN       21
# 840         24.7 - 25.8            NaN       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = us["Value"]
month = us["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="blue", label="Symptoms of Depressive Disorder")
# covid, = plt.plot(percentage, month, color="purple", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("United States")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# Regression Analysis
plt.ylim(0,ax_csv["Value"].max()) 

x_values = us['Weeknum']
y_values = us['Value']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y =" + str(round(slope,2)) + "x +" + str(round(intercept,2))

plt.annotate(line_eq, (20,40), fontsize = 15, color="blue")

plt.plot(x_values, regress_values, "r-")

plt.ylim(0,ax_csv["Value"].max())

plt.plot(x_values, np.full((12,),8.2), color="orange")

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

print(f"R Val is {rvalue**2}")

plt.show()
# Out:
# R Val is 0.8908174597951823
