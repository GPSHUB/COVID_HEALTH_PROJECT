# %%
## LeoZ_Notebook
# Dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
## import plotly.graph_objects as go
from scipy.stats import linregress

# %%
# Import csv files
ax_csv = pd.read_csv("../Resources/ad_clean.csv")
ax_csv.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup  Week Week Label  Value  Low CI  High CI Confidence Interval  \
# 0  United States     1  4/23/2020   23.5    22.7     24.3         22.7 - 24.3
# 1  18 - 29 years     1  4/23/2020   32.7    30.2     35.2         30.2 - 35.2
# 2  30 - 39 years     1  4/23/2020   25.7    24.1     27.3         24.1 - 27.3
# 3  40 - 49 years     1  4/23/2020   24.8    23.3     26.2         23.3 - 26.2
# 4  50 - 59 years     1  4/23/2020   23.2    21.5     25.0         21.5 - 25.0
#
#   Quartile range  Weeknum
# 0            NaN       17
# 1            NaN       17
# 2            NaN       17
# 3            NaN       17
# 4            NaN       17

# %%
ax_csv.dtypes
# Out:
# Indicator               object
# Group                   object
# State                   object
# Subgroup                object
# Week                     int64
# Week Label              object
# Value                  float64
# Low CI                 float64
# High CI                float64
# Confidence Interval     object
# Quartile range          object
# Weeknum                  int64
# dtype: object

# %%
cal = ax_csv.loc[(ax_csv["State"]=="California")&(ax_csv["Subgroup"]=="California")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
cal.head()
# Out:
#                         Indicator     Group       State    Subgroup  Week  \
# 93   Symptoms of Anxiety Disorder  By State  California  California     1
# 303  Symptoms of Anxiety Disorder  By State  California  California     2
# 513  Symptoms of Anxiety Disorder  By State  California  California     3
# 723  Symptoms of Anxiety Disorder  By State  California  California     4
# 933  Symptoms of Anxiety Disorder  By State  California  California     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 93   4/23/2020   30.8    28.2     33.5         28.2 - 33.5    30.4 - 31.6
# 303   5/7/2020   31.4    27.4     35.6         27.4 - 35.6    28.8 - 31.5
# 513  5/14/2020   32.3    29.0     35.7         29.0 - 35.7      28.9-36.1
# 723  5/21/2020   30.4    27.4     33.6         27.4 - 33.6      28.7-30.6
# 933  5/28/2020   33.8    31.5     36.2         31.5 - 36.2      31.8-37.1
#
#      Weeknum
# 93        17
# 303       19
# 513       20
# 723       21
# 933       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = cal["Value"]
month = cal["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="red", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="red", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("California")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

plt.show()

# %%
tx = ax_csv.loc[(ax_csv["State"]=="Texas")&(ax_csv["Subgroup"]=="Texas")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
tx.head()
# Out:
#                         Indicator     Group  State Subgroup  Week Week Label  \
# 132  Symptoms of Anxiety Disorder  By State  Texas    Texas     1  4/23/2020
# 342  Symptoms of Anxiety Disorder  By State  Texas    Texas     2   5/7/2020
# 552  Symptoms of Anxiety Disorder  By State  Texas    Texas     3  5/14/2020
# 762  Symptoms of Anxiety Disorder  By State  Texas    Texas     4  5/21/2020
# 972  Symptoms of Anxiety Disorder  By State  Texas    Texas     5  5/28/2020
#
#      Value  Low CI  High CI Confidence Interval Quartile range  Weeknum
# 132   29.7    25.9     33.7         25.9 - 33.7    27.9 - 30.3       17
# 342   32.4    28.2     36.9         28.2 - 36.9    31.6 - 38.3       19
# 552   28.8    26.1     31.7         26.1 - 31.7      27.5-28.8       20
# 762   32.6    29.0     36.3         29.0 - 36.3      30.7-36.0       21
# 972   31.1    27.7     34.6         27.7 - 34.6      29.7-31.7       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = tx["Value"]
month = tx["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="blue", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="blue", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Texas")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

plt.show()

# %%
ga = ax_csv.loc[(ax_csv["State"]=="Georgia")&(ax_csv["Subgroup"]=="Georgia")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
ga.head()
# Out:
#                         Indicator     Group    State Subgroup  Week  \
# 99   Symptoms of Anxiety Disorder  By State  Georgia  Georgia     1
# 309  Symptoms of Anxiety Disorder  By State  Georgia  Georgia     2
# 519  Symptoms of Anxiety Disorder  By State  Georgia  Georgia     3
# 729  Symptoms of Anxiety Disorder  By State  Georgia  Georgia     4
# 939  Symptoms of Anxiety Disorder  By State  Georgia  Georgia     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 99   4/23/2020   31.9    28.1     35.9         28.1 - 35.9    31.7 - 37.0
# 309   5/7/2020   29.5    24.2     35.4         24.2 - 35.4    28.8 - 31.5
# 519  5/14/2020   27.6    23.7     31.7         23.7 - 31.7      27.5-28.8
# 729  5/21/2020   32.6    28.6     36.8         28.6 - 36.8      30.7-36.0
# 939  5/28/2020   31.7    27.8     35.8         27.8 - 35.8      29.7-31.7
#
#      Weeknum
# 99        17
# 309       19
# 519       20
# 729       21
# 939       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = ga["Value"]
month = ga["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="orange", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="orange", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Georgia")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

plt.show()

# %%
fla = ax_csv.loc[(ax_csv["State"]=="Florida")&(ax_csv["Subgroup"]=="Florida")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
fla.head()
# Out:
#                         Indicator     Group    State Subgroup  Week  \
# 98   Symptoms of Anxiety Disorder  By State  Florida  Florida     1
# 308  Symptoms of Anxiety Disorder  By State  Florida  Florida     2
# 518  Symptoms of Anxiety Disorder  By State  Florida  Florida     3
# 728  Symptoms of Anxiety Disorder  By State  Florida  Florida     4
# 938  Symptoms of Anxiety Disorder  By State  Florida  Florida     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 98   4/23/2020   32.6    29.7     35.6         29.7 - 35.6    31.7 - 37.0
# 308   5/7/2020   27.6    23.1     32.5         23.1 - 32.5    26.3 - 28.7
# 518  5/14/2020   28.2    25.1     31.4         25.1 - 31.4      27.5-28.8
# 728  5/21/2020   34.1    31.2     37.2         31.2 - 37.2      30.7-36.0
# 938  5/28/2020   33.8    30.3     37.5         30.3 - 37.5      31.8-37.1
#
#      Weeknum
# 98        17
# 308       19
# 518       20
# 728       21
# 938       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = fla["Value"]
month = fla["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="green", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="green", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Florida")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())

# plt.legend(handles=[anxiety, covid], loc="best")

# plt.grid()

plt.show()

# %%
sd = ax_csv.loc[(ax_csv["State"]=="South Dakota")&(ax_csv["Subgroup"]=="South Dakota")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
sd.head()
# Out:
#                         Indicator     Group         State      Subgroup  Week  \
# 130  Symptoms of Anxiety Disorder  By State  South Dakota  South Dakota     1
# 340  Symptoms of Anxiety Disorder  By State  South Dakota  South Dakota     2
# 550  Symptoms of Anxiety Disorder  By State  South Dakota  South Dakota     3
# 760  Symptoms of Anxiety Disorder  By State  South Dakota  South Dakota     4
# 970  Symptoms of Anxiety Disorder  By State  South Dakota  South Dakota     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 130  4/23/2020   22.1    17.3     27.6         17.3 - 27.6    21.7 - 27.8
# 340   5/7/2020   26.1    17.9     35.7         17.9 - 35.7    20.3 - 26.2
# 550  5/14/2020   22.3    16.4     29.1         16.4 - 29.1      19.0-25.2
# 760  5/21/2020   30.4    24.6     36.6         24.6 - 36.6      28.7-30.6
# 970  5/28/2020   26.3    21.8     31.1         21.8 - 31.1      18.4-26.7
#
#      Weeknum
# 130       17
# 340       19
# 550       20
# 760       21
# 970       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = sd["Value"]
month = sd["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="yellow", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="yellow", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("South Dakota")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())
# Out:
# (0.0, 55.0)

# %%
md = ax_csv.loc[(ax_csv["State"]=="Maryland")&(ax_csv["Subgroup"]=="Maryland")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
md.head()
# Out:
#                         Indicator     Group     State  Subgroup  Week  \
# 109  Symptoms of Anxiety Disorder  By State  Maryland  Maryland     1
# 319  Symptoms of Anxiety Disorder  By State  Maryland  Maryland     2
# 529  Symptoms of Anxiety Disorder  By State  Maryland  Maryland     3
# 739  Symptoms of Anxiety Disorder  By State  Maryland  Maryland     4
# 949  Symptoms of Anxiety Disorder  By State  Maryland  Maryland     5
#
#     Week Label  Value  Low CI  High CI Confidence Interval Quartile range  \
# 109  4/23/2020   27.7    24.6     31.1         24.6 - 31.1    21.7 - 27.8
# 319   5/7/2020   30.1    24.2     36.6         24.2 - 36.6    28.8 - 31.5
# 529  5/14/2020   28.3    25.1     31.7         25.1 - 31.7      27.5-28.8
# 739  5/21/2020   25.8    21.8     30.0         21.8 - 30.0      24.8-28.6
# 949  5/28/2020   26.1    22.7     29.6         22.7 - 29.6      18.4-26.7
#
#      Weeknum
# 109       17
# 319       19
# 529       20
# 739       21
# 949       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = md["Value"]
month = md["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="purple", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="purple", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("Maryland")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())
# Out:
# (0.0, 55.0)

# %%
us = ax_csv.loc[(ax_csv["State"]=="United States")&(ax_csv["Subgroup"]=="United States")&(ax_csv["Indicator"]=="Symptoms of Anxiety Disorder")]
us.head()
# Out:
#                         Indicator              Group          State  \
# 70   Symptoms of Anxiety Disorder  National Estimate  United States
# 280  Symptoms of Anxiety Disorder  National Estimate  United States
# 490  Symptoms of Anxiety Disorder  National Estimate  United States
# 700  Symptoms of Anxiety Disorder  National Estimate  United States
# 910  Symptoms of Anxiety Disorder  National Estimate  United States
#
#           Subgroup  Week Week Label  Value  Low CI  High CI  \
# 70   United States     1  4/23/2020   30.8    30.0     31.7
# 280  United States     2   5/7/2020   30.0    28.9     31.0
# 490  United States     3  5/14/2020   28.2    27.6     28.9
# 700  United States     4  5/21/2020   29.4    28.8     30.1
# 910  United States     5  5/28/2020   30.6    30.0     31.2
#
#     Confidence Interval Quartile range  Weeknum
# 70          30.0 - 31.7            NaN       17
# 280         28.9 - 31.0            NaN       19
# 490         27.6 - 28.9            NaN       20
# 700         28.8 - 30.1            NaN       21
# 910         30.0 - 31.2            NaN       22

# %%
# Create the X and Y axis list

# Value = np.arange(0,100,10)
percentage = us["Value"]
month = us["Weeknum"]

# Plot the charts
anxiety = plt.plot(month, percentage, color="maroon", label="Symptoms of Anxiety Disorder")
# covid, = plt.plot(percentage, month, color="purple", label="Covid")

# Add labels to X and Y axes and titles 
plt.title("United States")
plt.xlabel("Weeknum")
plt.ylabel("Percentage")

# Set the limits for the X and Y axes
# plt.xlim(0,52)
plt.ylim(0,ax_csv["Value"].max())
# Out:
# (0.0, 55.0)
